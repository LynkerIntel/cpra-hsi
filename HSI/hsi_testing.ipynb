# %%
import numpy as np
import matplotlib.pyplot as plt

import AlligatorHSI

# %%
pct_open_water = np.random.rand(25, 10)
avg_water_depth_rlt_mrsh_srf = np.random.rand(25, 10)

# %%
shape = pct_open_water.shape

# %%
test = AlligatorHSI.AlligatorHSI(
    v1_pct_open_water=pct_open_water,
    v2_avg_water_depth_rlt_marsh_surface=avg_water_depth_rlt_mrsh_srf,
)
# Out:
# 2024-10-17 15:51:18,586 - AlligatorHSI - INFO - Using attribute v1_pct_open_water as shape for output: (25, 10)
# 2024-10-17 15:51:18,586 - AlligatorHSI - INFO - Running SI 1
# 2024-10-17 15:51:18,586 - AlligatorHSI - INFO - Running SI 2
# 2024-10-17 15:51:18,587 - AlligatorHSI - INFO - Pct habitat types data not provided. Setting index to 1.
# 2024-10-17 15:51:18,587 - AlligatorHSI - INFO - Edge data not provided. Setting index to 1.
# 2024-10-17 15:51:18,587 - AlligatorHSI - INFO - mean annual salinity data not provided. Setting index to 1.

# %%
plt.imshow(si_1)
plt.colorbar()

# %%
import matplotlib.pyplot as plt

plt.imshow(test.hsi)
plt.colorbar()

# %%
import numpy as np

# Example array
arr = np.array([1, 2, 3, 4, 5])

# %%
# Define functions for different conditions
num = 44


def square(x):
    return x**2


def cube(x):
    return x**3


def quad(x, num=44):
    return x**4 * num


# Function dictionary based on conditions
def apply_conditional_func(x):
    # if x < 3:
    #     return square(x)
    if x > 5:
        return cube(x)
    elif x == 2:
        return quad(x, 13)
    else:
        return quad(x)


# Vectorize and apply the conditional function
vectorized_func = np.vectorize(apply_conditional_func)
result = vectorized_func(arr)

# %%
result
# Out:
# array([   44,   208,  3564, 11264, 27500])
