# %%
import numpy as np

import AlligatorHSI

# %%
pct_open_water = np.random.rand(25, 10)
avg_water_depth_rlt_mrsh_srf = np.random.rand(25, 10)

# %%
test = AlligatorHSI.AlligatorHSI(
    v1_pct_open_water=pct_open_water,
    v2_avg_water_depth_rlt_marsh_surface=avg_water_depth_rlt_mrsh_srf,
)
# Out:
# 2024-10-17 15:16:31,719 - AlligatorHSI - INFO - Using attribute v1_pct_open_water as shape for output
# 2024-10-17 15:16:31,720 - AlligatorHSI - INFO - Running SI 1
# 2024-10-17 15:16:31,722 - AlligatorHSI - INFO - Running SI 2
# 2024-10-17 15:16:31,724 - AlligatorHSI - INFO - Pct habitat types data not provided. Setting index to 1.
# 2024-10-17 15:16:31,726 - AlligatorHSI - INFO - Edge data not provided. Setting index to 1.
# 2024-10-17 15:16:31,727 - AlligatorHSI - INFO - mean annual salinity data not provided. Setting index to 1.

# %%
import matplotlib.pyplot as plt

plt.imshow(test.hsi)
plt.colorbar()
