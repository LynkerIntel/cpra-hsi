# %%
import numpy as np

import AlligatorHSI

# %%
pct_open_water = np.random.rand(3196, 1275)

# %%
test = AlligatorHSI.AlligatorHSI(v1_pct_open_water=pct_open_water)
# Out:
# 2024-10-17 11:36:37,807 - AlligatorHSI - INFO - Using attribute v1_pct_open_water as shape for output
# 2024-10-17 11:36:37,892 - AlligatorHSI - INFO - avg annual water depth relative to marsh surface data not provided. Setting temperature suitability index to 1.
# 2024-10-17 11:36:37,895 - AlligatorHSI - INFO - Pct habitat types data not provided. Setting temperature suitability index to 1.
# 2024-10-17 11:36:37,898 - AlligatorHSI - INFO - Edge data not provided. Setting temperature suitability index to 1.
# 2024-10-17 11:36:37,903 - AlligatorHSI - INFO - mean annual salinity data not provided. Setting temperature suitability index to 1.

# %%
import matplotlib.pyplot as plt

plt.imshow(test.hsi)
