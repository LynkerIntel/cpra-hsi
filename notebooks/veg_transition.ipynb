# %%
import xarray as xr

# %%
ds = xr.open_dataset(
    "/Users/dillonragar/Downloads/AMP_LULC_60m_Nearest_Resample/AMP_LULC_60m_Nearest_Resample.tif",
    engine="rasterio",
)

# %%
ds["band_data"].plot()
